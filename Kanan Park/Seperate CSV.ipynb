# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from os import listdir

# %%
df = pd.read_csv('Thumbs150 results.csv')
df.head()
# Out:
#    Unnamed: 0   Type  ... Content                                               Path
# 0           0  Train  ...   Fruit  thumbs150/GenevieveBottiAcercampestre739905239...
# 1           1  Train  ...   Fruit  thumbs150/GregoireDucheAcercampestre3244631583...
# 2           2  Train  ...   Fruit  thumbs150/GregoireDucheAcercampestre3244631172...
# 3           3  Train  ...   Fruit   thumbs150/HerveGoeauAcercampestre75435020840.jpg
# 4           4  Train  ...   Fruit   thumbs150/HerveGoeauAcercampestre75435033415.jpg
#
# [5 rows x 5 columns]

# %%
train_cond = df['Type'] == 'Train'
train = df[train_cond]
train = train.drop(['Unnamed: 0'], axis = 1)
train
# Out:
#         Type  ...                                               Path
# 0      Train  ...  thumbs150/GenevieveBottiAcercampestre739905239...
# 1      Train  ...  thumbs150/GregoireDucheAcercampestre3244631583...
# 2      Train  ...  thumbs150/GregoireDucheAcercampestre3244631172...
# 3      Train  ...   thumbs150/HerveGoeauAcercampestre75435020840.jpg
# 4      Train  ...   thumbs150/HerveGoeauAcercampestre75435033415.jpg
# ...      ...  ...                                                ...
# 26068  Train  ...  thumbs150/GregoireDucheVitexagnus-castus324315...
# 26069  Train  ...  thumbs150/GregoireDucheVitexagnus-castus324315...
# 26070  Train  ...  thumbs150/LilianeRoubaudiVitexagnus-castus9023...
# 26071  Train  ...  thumbs150/LilianeRoubaudiVitexagnus-castus9023...
# 26076  Train  ...  thumbs150/LilianeRoubaudiVitexagnus-castus8995...
#
# [20985 rows x 4 columns]

# %%
#train_results = train.to_csv('train_results.csv')

# %%
leaf_cond = df['Content'] == 'Leaf'
leaf = train[leaf_cond]
leaf_results = train.to_csv('leaf_results.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#         Type  ...                                               Path
# 9      Train  ...  thumbs150/AnnickLarbouillatAcercampestre316887...
# 10     Train  ...  thumbs150/AnnickLarbouillatAcercampestre316887...
# 11     Train  ...   thumbs150/FrancoisGrandAcercampestre17414021.jpg
# 12     Train  ...  thumbs150/GregoireDucheAcercampestre3244551589...
# 13     Train  ...  thumbs150/GregoireDucheAcercampestre3244553346...
# ...      ...  ...                                                ...
# 25954  Train  ...  thumbs150/PierreBonnetVitexagnus-castus2631524...
# 25955  Train  ...  thumbs150/PierreBonnetVitexagnus-castus269930.jpg
# 25956  Train  ...  thumbs150/PierreBonnetVitexagnus-castus261121.jpg
# 25957  Train  ...  thumbs150/PierreBonnetVitexagnus-castus2634304...
# 25958  Train  ...  thumbs150/PierreBonnetVitexagnus-castus5377037...
#
# ...

# %%
test_cond = df['Type'] == 'Test'
test = df[test_cond]
test = test.drop(['Unnamed: 0'], axis = 1)
test
# Out:
#        Type  ...                                               Path
# 7      Test  ...  thumbs150/MathieuMenandAcercampestre7224651367...
# 8      Test  ...  thumbs150/MathieuMenandAcercampestre7241593612...
# 69     Test  ...   thumbs150/AlexisJolyAcercampestre92388321458.jpg
# 70     Test  ...  thumbs150/GenevieveBottiAcercampestre741651965...
# 71     Test  ...  thumbs150/GenevieveBottiAcercampestre741651241...
# ...     ...  ...                                                ...
# 26060  Test  ...  thumbs150/MathieuMenandVitexagnus-castus721388...
# 26072  Test  ...  thumbs150/PierreBonnetVitexagnus-castus9516591...
# 26073  Test  ...  thumbs150/PierreBonnetVitexagnus-castus9516591...
# 26074  Test  ...  thumbs150/PierreBonnetVitexagnus-castus9516591...
# 26075  Test  ...  thumbs150/PierreBonnetVitexagnus-castus9516591...
#
# [5092 rows x 4 columns]

# %%
test_results = test.to_csv('test_results.csv')

# %%
leaf_cond = df['Content'] == 'SheetAsBackground'
leaf = test[leaf_cond]
leaf
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        Type  ...                                               Path
# 201    Test  ...   thumbs150/HerveGoeauAcercampestre92481912655.jpg
# 202    Test  ...    thumbs150/HerveGoeauAcercampestre9248192021.jpg
# 203    Test  ...   thumbs150/HerveGoeauAcercampestre92481919621.jpg
# 204    Test  ...   thumbs150/HerveGoeauAcercampestre92481924887.jpg
# 205    Test  ...   thumbs150/HerveGoeauAcercampestre92481915660.jpg
# ...     ...  ...                                                ...
# 26039  Test  ...  thumbs150/HerveGoeauVitexagnus-castus924693918...
# 26040  Test  ...  thumbs150/HerveGoeauVitexagnus-castus924693184...
# 26041  Test  ...  thumbs150/HerveGoeauVitexagnus-castus924693504...
# 26042  Test  ...  thumbs150/HerveGoeauVitexagnus-castus924693169...
# 26043  Test  ...  thumbs150/HerveGoeauVitexagnus-castus924693876...
#
# ...
